# %% [markdown]
# # Overview
#
# Describe the problem background, experiment objectives, dataset, and main evaluation metrics. Keep this section concise while providing enough context before moving into exploration and modeling.

# %% [markdown]
# # Reference-Based Exploration
#
# Use this section to replicate or follow the approach from the main reference. Document assumptions, important parameters, and any differences from the reference.

# %% [markdown]
# ## Preprocessing
#
# Explain the cleaning, transformation, feature engineering, and data splitting steps based on the reference. Include the rationale if any preprocessing step is adjusted.

# %% [markdown]
# ### Model Name
#
# Replace this heading with the model name, such as ARIMA, Prophet, XGBoost, LSTM, or another model. Briefly describe the initial configuration and why the model was selected.

# %% [markdown]
# #### Training
#
# Train the model using the training data. Record the parameters, duration or training notes, and important outputs such as loss or training scores if available.

# %% [markdown]
# #### Validation
#
# Evaluate the model on the validation data if used. Compare configurations and explain why the best model or parameter set was selected.

# %% [markdown]
# #### Testing
#
# Test the final model on the testing data. Report the main metrics, prediction vs actual visualizations, and a brief interpretation of model performance.

# %% [markdown]
# # Exploration Based on Our Preprocessing
#
# Use this section to run experiments with our own preprocessing design. Focus the discussion on how preprocessing changes affect model performance.

# %% [markdown]
# ## Preprocessing
#
# Explain our preprocessing pipeline, including data cleaning, feature transformation, missing value handling, scaling, encoding, or any other relevant steps.

# %% [markdown]
# ### Model Name
#
# Replace this heading with the model tested using our preprocessing. Explain the model configuration and how it differs from the reference-based experiment if applicable.

# %% [markdown]
# #### Training
#
# Train the model using the data from our preprocessing pipeline. Save the parameters, model artifacts, and training results needed to reproduce the experiment.

# %% [markdown]
# #### Validation
#
# Use validation to select the best configuration when multiple experiments are performed. Present the comparison results concisely and consistently.

# %% [markdown]
# #### Testing
#
# Evaluate the final model on the testing data. Compare the results with the reference-based experiment and explain whether our preprocessing improves performance.

# %% [markdown]
# # Summary
#
# Summarize the best results from all experiments. Mention the best model, best preprocessing approach, main metrics, key insights, experiment limitations, and recommended next steps.
#
# Recommended notebook structure:
#
# - Overview or background
# - Reference-based exploration
# - Reference preprocessing
# - Reference modeling per model
# - Exploration based on our preprocessing
# - Our preprocessing pipeline
# - Our modeling experiments per model
# - Summary and recommendations
